# %%
# !git clone -b feature/20260904.KhoaNA https://github.com/Khoawawa/DeepLearning_Framework.git
# Out:
# fatal: destination path 'DeepLearning_Framework' already exists and is not an empty directory.

# %%
# %cd DeepLearning_Framework
# Out:
# /content/DeepLearning_Framework

# %%
# !cat DeepLearning_Framework/main.sh
# Out:
# #!/bin/bash
# set -e
#
# BRANCH=${1:-main}
# PROFILE=${2:-dev}
# CONFIG=${3:-configs/config.yaml}
#
# if [ ! -d DeepLearning_Framework ]; then
#     git clone -b "$BRANCH" https://github.com/Khoawawa/DeepLearning_Framework.git
#     cd DeepLearning_Framework
# else
#     cd DeepLearning_Framework
#     git fetch origin
#     git checkout "$BRANCH"
#     git reset --hard origin/"$BRANCH"
# fi
#
# pip install -q -r requirements.txt
#
# PROFILE="$PROFILE" python main.py --config "$CONFIG"

# %%
# !bash main.sh feature/20260904.KhoaNA prod
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 911 bytes | 911.00 KiB/s, done.
# From https://github.com/Khoawawa/DeepLearning_Framework
#    3763b36..4f77f17  feature/20260904.KhoaNA -> origin/feature/20260904.KhoaNA
# Already on 'feature/20260904.KhoaNA'
# Your branch is behind 'origin/feature/20260904.KhoaNA' by 1 commit, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
# HEAD is now at 4f77f17 [KhoaNA] update main.sh and test.ipynb
# main.sh: line 16: [requirements.txt: command not found
# Traceback (most recent call last):
#   File "/content/DeepLearning_Framework/DeepLearning_Framework/main.py", line 6, in <module>
#     from engines.callbacks import build_callbacks
#   File "/content/DeepLearning_Framework/DeepLearning_Framework/engines/__init__.py", line 1, in <module>
#     from engines import trainer
#   File "/content/DeepLearning_Framework/DeepLearning_Framework/engines/trainer.py", line 12, in <module>
#     from loguru import logger
# ModuleNotFoundError: No module named 'loguru'

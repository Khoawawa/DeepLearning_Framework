# %%
# !git clone -b feature/20260904.KhoaNA https://github.com/Khoawawa/DeepLearning_Framework.git
# Out:
# Cloning into 'DeepLearning_Framework'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 297 (delta 11), reused 15 (delta 10), pack-reused 258 (from 1)
# Receiving objects: 100% (297/297), 75.07 KiB | 844.00 KiB/s, done.
# Resolving deltas: 100% (150/150), done.

# %%
# %cd DeepLearning_Framework
# Out:
# /content/DeepLearning_Framework

# %%
# !bash main.sh feature/20260904.KhoaNA prod
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 1.5 MB/s eta 0:00:0000:01
# 2026-09-18 06:32:58.561 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'smooth_l1' -> SmoothL1Loss
# 2026-09-18 06:32:58.561 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'mse' -> MSELoss
# 2026-09-18 06:32:58.562 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'l1' -> L1Loss
# 2026-09-18 06:32:58.562 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'cross_entropy' -> CrossEntropyLoss
# 2026-09-18 06:32:58.562 | DEBUG    | utils.common_utils:decorator:144 - Registered trainer_builder 'cnn' -> CNNTrainer
# 2026-09-18 06:32:58.564 | DEBUG    | utils.common_utils:decorator:144 - Registered callback 'checkpoint' -> CheckpointCallBack
# 2026-09-18 06:32:58.564 | DEBUG    | utils.common_utils:decorator:144 - Registered callback 'logging' -> LoggingCallBack
# 06:32:58 | INFO     | Logging configured for profile 'prod' (terminal level=INFO)
# 06:32:58 | INFO     | Set seed to 42
# 06:32:58 | INFO     | Using default device
# 06:32:58 | INFO     | Config path configs/config.yaml is absolute or exists
# 06:32:58 | INFO     | Resolving config path model/cnn.yaml to /content/DeepLearning_Framework/configs/model/cnn.yaml
# 06:32:58 | INFO     | Resolving config path data/dummy.yaml to /content/DeepLearning_Framework/configs/data/dummy.yaml
# 06:32:58 | INFO     | Loaded merged config from configs/config.yaml
# 06:32:58 | INFO     | Set output path to be /runs/cnn
# 06:33:08 | INFO     | Using default general factory
# 06:33:08 | INFO     | Built callbacks: CheckpointCallBack, LoggingCallBack
# 06:33:09 | INFO     | Built dataloader with 10 batches
#   0% 0/10 [00:00<?, ?it/s]06:33:09 | INFO     | step=0 loss=0.4961
# 100% 10/10 [00:00<00:00, 51.02it/s]
# 06:33:09 | INFO     | Saved checkpoint to /runs/cnn/latest.pt
# 06:33:09 | INFO     | Epoch 0 complete — avg(loss=0.4305)
# 100% 10/10 [00:00<00:00, 160.38it/s]
# 06:33:09 | INFO     | Saved checkpoint to /runs/cnn/latest.pt
# 06:33:09 | INFO     | Epoch 1 complete — avg(loss=0.3124)
# 100% 10/10 [00:00<00:00, 161.36it/s]
# 06:33:09 | INFO     | Saved checkpoint to /runs/cnn/latest.pt
# 06:33:09 | INFO     | Epoch 2 complete — avg(loss=0.2343)
# 06:33:09 | INFO     | Saved checkpoint to /runs/cnn/final.pt
# 06:33:09 | INFO     | Finished

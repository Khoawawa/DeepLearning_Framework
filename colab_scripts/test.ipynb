# %%
# !git clone -b feature/20260904.KhoaNA https://github.com/Khoawawa/DeepLearning_Framework.git
# Out:
# Cloning into 'DeepLearning_Framework'...
# remote: Enumerating objects: 276, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 276 (delta 141), reused 203 (delta 86), pack-reused 0 (from 0)
# Receiving objects: 100% (276/276), 72.29 KiB | 4.25 MiB/s, done.
# Resolving deltas: 100% (141/141), done.

# %%
# %cd DeepLearning_Framework
# Out:
# /content/DeepLearning_Framework

# %%
# %pip install -r requirements.txt
# Out:
# Collecting loguru (from -r requirements.txt (line 1))
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 2)) (2.11.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 3)) (0.26.0+cpu)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 6)) (4.16.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 7)) (1.0.29)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 2)) (3.32.5)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 2)) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch->-r requirements.txt (line 2)) (2025.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from torchvision->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from torchvision->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.13/dist-packages (from timm->-r requirements.txt (line 7)) (1.29.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.13/dist-packages (from timm->-r requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 7)) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub->timm->-r requirements.txt (line 7)) (26.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 7)) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 7)) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 7)) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm->-r requirements.txt (line 7)) (0.16.0)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.3

# %%
# !python main.py --config configs/config.yaml
# Out:
# 2026-09-18 04:46:48.565 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'smooth_l1' -> SmoothL1Loss
# 2026-09-18 04:46:48.565 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'mse' -> MSELoss
# 2026-09-18 04:46:48.566 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'l1' -> L1Loss
# 2026-09-18 04:46:48.566 | DEBUG    | utils.common_utils:decorator:144 - Registered criterion 'cross_entropy' -> CrossEntropyLoss
# 2026-09-18 04:46:48.566 | DEBUG    | utils.common_utils:decorator:144 - Registered trainer_builder 'cnn' -> CNNTrainer
# 2026-09-18 04:46:48.566 | DEBUG    | utils.common_utils:decorator:144 - Registered callback 'checkpoint' -> CheckpointCallBack
# 2026-09-18 04:46:48.567 | DEBUG    | utils.common_utils:decorator:144 - Registered callback 'logging' -> LoggingCallBack
# 04:46:48 | INFO     | Logging configured for profile 'dev' (terminal level=DEBUG)
# 04:46:48 | INFO     | Set seed to 42
# 04:46:48 | INFO     | Using default device
# 04:46:48 | INFO     | Config path configs/config.yaml is absolute or exists
# 04:46:48 | DEBUG    | Loaded config from configs/config.yaml
# 04:46:48 | INFO     | Resolving config path model/cnn.yaml to /content/DeepLearning_Framework/configs/model/cnn.yaml
# 04:46:48 | DEBUG    | Loaded config from /content/DeepLearning_Framework/configs/model/cnn.yaml
# 04:46:48 | INFO     | Resolving config path data/dummy.yaml to /content/DeepLearning_Framework/configs/data/dummy.yaml
# 04:46:48 | DEBUG    | Loaded config from /content/DeepLearning_Framework/configs/data/dummy.yaml
# 04:46:48 | INFO     | Loaded merged config from configs/config.yaml
# 04:46:48 | INFO     | Set output path to be /runs/cnn
# 04:46:49 | DEBUG    | Registered dataset 'stl10' -> STL10Dataset
# 04:46:49 | DEBUG    | Registered dataset 'cifar10' -> CIFAR10Dataset
# 04:46:49 | DEBUG    | Registered dataset 'dummy' -> DummyImageDataset
# 04:46:51 | INFO     | Using default general factory
# 04:46:51 | INFO     | Built callbacks: CheckpointCallBack, LoggingCallBack
# 04:46:51 | ERROR    | TypeError: '<=' not supported between instances of 'NoneType' and 'int'  (/content/DeepLearning_Framework/main.py:89)
# 04:46:51 | DEBUG    | Full traceback
# Traceback (most recent call last):
#   File "/content/DeepLearning_Framework/main.py", line 117, in main
#     run(args)
#   File "/content/DeepLearning_Framework/main.py", line 89, in run
#     if num_epochs <= 0:
# TypeError: '<=' not supported between instances of 'NoneType' and 'int'
